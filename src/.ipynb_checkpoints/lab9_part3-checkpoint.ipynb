# %% [markdown]
# # Lab 9

# %%
import numpy as np 
import pandas as pd
from sklearn import cluster
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
from scipy.spatial import distance

# %% [markdown]
# ## Part 3

# %% [markdown]
# ### Compound Dataset

# %%
#importing the data 
#Load the data
compound_data = pd.read_csv("../data/compound.txt", sep="\t", header = None)
compound_data.columns = ['feature_1', 'feature_2', 'class']
compound_data_new = compound_data.drop('class', axis=1)
compound_data_new.head()
# Out:
#    feature_1  feature_2
# 0      26.75      22.15
# 1      29.80      22.15
# 2      31.55      21.10
# 3      27.70      20.85
# 4      29.90      19.95

# %%
N,d = compound_data_new.shape
compound_data_new_delta = pd.DataFrame(100*np.divide(compound_data_new.iloc[1:,:].values-compound_data_new.iloc[:N-1,:].values, 
                                   compound_data_new.iloc[:N-1,:].values), columns=compound_data_new.columns, 
                                   index=compound_data_new.iloc[1:].index)
compound_data_new_delta.head()
# Out:
#    feature_1  feature_2
# 1  11.401869   0.000000
# 2   5.872483  -4.740406
# 3 -12.202853  -1.184834
# 4   7.942238  -4.316547
# 5 -10.367893  -4.511278

# %% [markdown]
# #### Relative Density = Inverse of Distance:

# %% [markdown]
# ##### k=2

# %%
knn = 2
nbrs = NearestNeighbors(n_neighbors=knn, metric=distance.euclidean).fit(compound_data_new.values)
distances, indices = nbrs.kneighbors(compound_data_new.values)

inverse_distances_1 = 1/distances
anomaly_score_1 = inverse_distances_1[:,knn-1]

anom = pd.DataFrame(anomaly_score_1, index=compound_data_new.index, columns=['Anomaly score'])
result = pd.concat((compound_data_new,anom), axis=1)
result.nlargest(5,'Anomaly score') #top-5 points
# Out:
# <ipython-input-99-7a3d3e8ee0af>:5: RuntimeWarning: divide by zero encountered in true_divide
#   inverse_distances_1 = 1/distances
#      feature_1  feature_2  Anomaly score
# 164      10.80      19.60       3.429972
# 166      10.65      19.35       3.429972
# 392      16.05       9.35       3.333333
# 393      16.05       9.65       3.333333
# 387      16.45      10.10       3.287980

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
p = ax.scatter(compound_data_new.feature_1,compound_data_new.feature_2,c=anomaly_score_1,cmap='jet')
ax.set_xlabel('feature_1')
ax.set_ylabel('feature_2')
fig.colorbar(p)
plt.show()

# %% [markdown]
# ##### k=5

# %%
knn = 5
nbrs = NearestNeighbors(n_neighbors=knn, metric=distance.euclidean).fit(compound_data_new.values)
distances, indices = nbrs.kneighbors(compound_data_new.values)

inverse_distances_2 = 1/distances
anomaly_score_2 = inverse_distances_2[:,knn-1]

anom = pd.DataFrame(anomaly_score_2, index=compound_data_new.index, columns=['Anomaly score'])
result = pd.concat((compound_data_new,anom), axis=1)
result.nlargest(5,'Anomaly score') #top-5 points
# Out:
# <ipython-input-102-caffee08ff72>:5: RuntimeWarning: divide by zero encountered in true_divide
#   inverse_distances_2 = 1/distances
#      feature_1  feature_2  Anomaly score
# 166      10.65      19.35       2.480695
# 209      18.85      18.90       2.425356
# 58       33.05      18.50       2.119996
# 330      18.00      11.95       2.108185
# 393      16.05       9.65       2.030692

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
p = ax.scatter(compound_data_new.feature_1,compound_data_new.feature_2,c=anomaly_score_2,cmap='jet')
ax.set_xlabel('feature_1')
ax.set_ylabel('feature_2')
fig.colorbar(p)
plt.show()

# %% [markdown]
# #### Relative Density = Inverse of Average Distance:

# %%
anomaly_score_avg = (anomaly_score_1 + anomaly_score_2) / 2

anom = pd.DataFrame(anomaly_score_avg, index=compound_data_new.index, columns=['Anomaly score'])
result = pd.concat((compound_data_new,anom), axis=1)
result.nlargest(5,'Anomaly score') #top-5 points
# Out:
#      feature_1  feature_2  Anomaly score
# 166      10.65      19.35       2.955333
# 393      16.05       9.65       2.682013
# 164      10.80      19.60       2.672812
# 209      18.85      18.90       2.586284
# 388      16.50       9.80       2.572467

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
p = ax.scatter(compound_data_new.feature_1,compound_data_new.feature_2,c=anomaly_score_avg,cmap='jet')
ax.set_xlabel('feature_1')
ax.set_ylabel('feature_2')
fig.colorbar(p)
plt.show()

# %% [markdown]
# ### Flame Dataset

# %%
#importing the data 
#Load the data
flame_data = pd.read_csv("../data/flame.txt", sep="\t", header = None)
flame_data.columns = ['feature_1', 'feature_2', 'class']
flame_data_new = flame_data.drop('class', axis=1)
flame_data_new.head()
# Out:
#    feature_1  feature_2
# 0       1.85      27.80
# 1       1.35      26.65
# 2       1.40      23.25
# 3       0.85      23.05
# 4       0.50      22.35

# %%
N,d = flame_data_new.shape
flame_data_new_delta = pd.DataFrame(100*np.divide(flame_data_new.iloc[1:,:].values-flame_data_new.iloc[:N-1,:].values, 
                                   flame_data_new.iloc[:N-1,:].values), columns=flame_data_new.columns, 
                                   index=flame_data_new.iloc[1:].index)
flame_data_new_delta.head()
# Out:
#    feature_1  feature_2
# 1 -27.027027  -4.136691
# 2   3.703704 -12.757974
# 3 -39.285714  -0.860215
# 4 -41.176471  -3.036876
# 5  30.000000  -4.474273

# %% [markdown]
# #### Relative Density = Inverse of Distance:

# %% [markdown]
# ##### k=2

# %%
knn = 2
nbrs = NearestNeighbors(n_neighbors=knn, metric=distance.euclidean).fit(flame_data_new.values)
distances, indices = nbrs.kneighbors(flame_data_new.values)

inverse_distances_1 = 1/distances
anomaly_score_1 = inverse_distances_1[:,knn-1]

anom = pd.DataFrame(anomaly_score_1, index=flame_data_new.index, columns=['Anomaly score'])
result = pd.concat((flame_data_new,anom), axis=1)
result.nlargest(5,'Anomaly score') #top-5 points
# Out:
# <ipython-input-106-a933aa365ea9>:5: RuntimeWarning: divide by zero encountered in true_divide
#   inverse_distances_1 = 1/distances
#      feature_1  feature_2  Anomaly score
# 72        7.40      16.20       2.480695
# 74        7.35      15.80       2.480695
# 229       7.40      25.25       2.425356
# 236       7.50      25.65       2.425356
# 61        6.60      17.65       2.425356

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
p = ax.scatter(flame_data_new.feature_1,flame_data_new.feature_2,c=anomaly_score_1,cmap='jet')
ax.set_xlabel('feature_1')
ax.set_ylabel('feature_2')
fig.colorbar(p)
plt.show()

# %% [markdown]
# ##### k=5

# %%
knn = 5
nbrs = NearestNeighbors(n_neighbors=knn, metric=distance.euclidean).fit(flame_data_new.values)
distances, indices = nbrs.kneighbors(flame_data_new.values)

inverse_distances_2 = 1/distances
anomaly_score_2 = inverse_distances_2[:,knn-1]

anom = pd.DataFrame(anomaly_score_2, index=flame_data_new.index, columns=['Anomaly score'])
result = pd.concat((flame_data_new,anom), axis=1)
result.nlargest(5,'Anomaly score') #top-5 points
# Out:
# <ipython-input-108-40dc4d063175>:5: RuntimeWarning: divide by zero encountered in true_divide
#   inverse_distances_2 = 1/distances
#      feature_1  feature_2  Anomaly score
# 216       7.90      25.30       1.881442
# 236       7.50      25.65       1.818182
# 219       7.55      24.85       1.754116
# 65        7.15      17.80       1.754116
# 68        7.30      17.25       1.666667

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
p = ax.scatter(flame_data_new.feature_1,flame_data_new.feature_2,c=anomaly_score_2,cmap='jet')
ax.set_xlabel('feature_1')
ax.set_ylabel('feature_2')
fig.colorbar(p)
plt.show()

# %% [markdown]
# #### Relative Density = Inverse of Average Distance:

# %%
anomaly_score_avg = (anomaly_score_1 + anomaly_score_2) / 2

anom = pd.DataFrame(anomaly_score_avg, index=flame_data_new.index, columns=['Anomaly score'])
result = pd.concat((flame_data_new,anom), axis=1)
result.nlargest(5,'Anomaly score') #top-5 points
# Out:
#      feature_1  feature_2  Anomaly score
# 236       7.50      25.65       2.121769
# 219       7.55      24.85       2.047469
# 216       7.90      25.30       2.025373
# 229       7.40      25.25       2.003248
# 67        6.70      17.25       2.003248

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
p = ax.scatter(flame_data_new.feature_1,flame_data_new.feature_2,c=anomaly_score_avg,cmap='jet')
ax.set_xlabel('feature_1')
ax.set_ylabel('feature_2')
fig.colorbar(p)
plt.show()

# %% [markdown]
# ### Pathbased Dataset

# %%
#importing the data 
#Load the data
pathbased_data = pd.read_csv("../data/pathbased.txt", sep="\t", header = None)
pathbased_data.columns = ['feature_1', 'feature_2', 'class']
pathbased_data_new = pathbased_data.drop('class', axis=1)
pathbased_data_new.head()
# Out:
#    feature_1  feature_2
# 0      11.25       5.05
# 1      10.95       4.70
# 2       9.85       5.80
# 3       9.80       5.75
# 4       9.15       6.80

# %%
N,d = pathbased_data_new.shape
pathbased_data_new_delta = pd.DataFrame(100*np.divide(pathbased_data_new.iloc[1:,:].values-pathbased_data_new.iloc[:N-1,:].values, 
                                   pathbased_data_new.iloc[:N-1,:].values), columns=pathbased_data_new.columns, 
                                   index=pathbased_data_new.iloc[1:].index)
pathbased_data_new_delta.head()
# Out:
#    feature_1  feature_2
# 1  -2.666667  -6.930693
# 2 -10.045662  23.404255
# 3  -0.507614  -0.862069
# 4  -6.632653  18.260870
# 5  -5.464481  -2.941176

# %% [markdown]
# #### Relative Density = Inverse of Distance:

# %% [markdown]
# ##### k=2

# %%
knn = 2
nbrs = NearestNeighbors(n_neighbors=knn, metric=distance.euclidean).fit(pathbased_data_new.values)
distances, indices = nbrs.kneighbors(pathbased_data_new.values)

inverse_distances_1 = 1/distances
anomaly_score_1 = inverse_distances_1[:,knn-1]

anom = pd.DataFrame(anomaly_score_1, index=pathbased_data_new.index, columns=['Anomaly score'])
result = pd.concat((pathbased_data_new,anom), axis=1)
result.nlargest(5,'Anomaly score') #top-5 points
# Out:
# <ipython-input-112-6df4aa823988>:5: RuntimeWarning: divide by zero encountered in true_divide
#   inverse_distances_1 = 1/distances
#      feature_1  feature_2  Anomaly score
# 133      26.40      14.35            inf
# 134      26.40      14.35            inf
# 117      27.95      14.65      20.000000
# 118      27.95      14.70      20.000000
# 131      27.10      14.55      14.142136

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
p = ax.scatter(pathbased_data_new.feature_1,pathbased_data_new.feature_2,c=anomaly_score_1,cmap='jet')
ax.set_xlabel('feature_1')
ax.set_ylabel('feature_2')
fig.colorbar(p)
plt.show()

# %% [markdown]
# ##### k=5

# %%
knn = 5
nbrs = NearestNeighbors(n_neighbors=knn, metric=distance.euclidean).fit(pathbased_data_new.values)
distances, indices = nbrs.kneighbors(pathbased_data_new.values)

inverse_distances_2 = 1/distances
anomaly_score_2 = inverse_distances_2[:,knn-1]

anom = pd.DataFrame(anomaly_score_2, index=pathbased_data_new.index, columns=['Anomaly score'])
result = pd.concat((pathbased_data_new,anom), axis=1)
result.nlargest(5,'Anomaly score') #top-5 points
# Out:
# <ipython-input-114-3cc21206b24f>:5: RuntimeWarning: divide by zero encountered in true_divide
#   inverse_distances_2 = 1/distances
#      feature_1  feature_2  Anomaly score
# 183      24.40      17.15       1.810715
# 221      10.90      15.95       1.581139
# 217      10.15      15.05       1.538462
# 252      12.70      15.60       1.538462
# 253      12.50      16.15       1.533930

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
p = ax.scatter(pathbased_data_new.feature_1,pathbased_data_new.feature_2,c=anomaly_score_2,cmap='jet')
ax.set_xlabel('feature_1')
ax.set_ylabel('feature_2')
fig.colorbar(p)
plt.show()

# %% [markdown]
# #### Relative Density = Inverse of Average Distance:

# %%
anomaly_score_avg = (anomaly_score_1 + anomaly_score_2) / 2

anom = pd.DataFrame(anomaly_score_avg, index=pathbased_data_new.index, columns=['Anomaly score'])
result = pd.concat((pathbased_data_new,anom), axis=1)
result.nlargest(5,'Anomaly score') #top-5 points
# Out:
#      feature_1  feature_2  Anomaly score
# 133      26.40      14.35            inf
# 134      26.40      14.35            inf
# 117      27.95      14.65      10.584206
# 118      27.95      14.70      10.579284
# 155      26.20      16.85       7.769498

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
p = ax.scatter(pathbased_data_new.feature_1,pathbased_data_new.feature_2,c=anomaly_score_avg,cmap='jet')
ax.set_xlabel('feature_1')
ax.set_ylabel('feature_2')
fig.colorbar(p)
plt.show()
